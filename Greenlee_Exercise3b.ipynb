# %%
install.packages("devtools")
devtools::install_github("sfsheath/cawd")
install.packages("sp")
# Out:
# Installing package into ‘/srv/rlibs’
# (as ‘lib’ is unspecified)
# Downloading GitHub repo sfsheath/cawd@master
# from URL https://api.github.com/repos/sfsheath/cawd/zipball/master
# Installing cawd
# '/usr/lib/R/bin/R' --no-site-file --no-environ --no-save --no-restore --quiet  \
#   CMD INSTALL '/tmp/RtmpcGGuCm/devtools2d29744c20/sfsheath-cawd-928f175'  \
#   --library='/srv/rlibs' --install-tests
#
# Installing package into ‘/srv/rlibs’
# (as ‘lib’ is unspecified)

# %%
library("sp")
library("cawd")
par(mai=c(0,0,0,0))
plot(awmc.roman.empire.200.sp)
# Out:
# plot without title

# %%
plot(	awmc.senatorial.sp)
# Out:
# plot without title

# %%
data()

# %%
plot(darmc.shipwrecks.sp)
plot(awmc.roman.territory.60bc.sp)
# Out:
# plot without title
# plot without title

# %%
plot(	darmc.rats.1to1500.sp)
# Out:
# plot without title
